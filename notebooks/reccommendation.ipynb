# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/tracks_features.csv')
df.head()
# Out:
#                        id                   name                      album  \
# 0  7lmeHLHBe4nmXzuXc0HDjk                Testify  The Battle Of Los Angeles
# 1  1wsRitfRRtWyEapl0q22o8        Guerrilla Radio  The Battle Of Los Angeles
# 2  1hR0fIFK2qRG3f3RF70pb7       Calm Like a Bomb  The Battle Of Los Angeles
# 3  2lbASgTSoDO7MTuLAXlTW0              Mic Check  The Battle Of Los Angeles
# 4  1MQTmpYOZ6fcMQc56Hdo7T  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                  album_id                       artists  \
# 0  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 1  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 2  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 3  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 4  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
#
#                    artist_ids  track_number  disc_number  explicit  \
# 0  ['2d0hyoQ5ynDBnkvAbJKORj']             1            1     False
# ...

# %%
#change song titles to lower case
df['name'] = df['name'].str.lower()
df.head()
# Out:
#                        id                   name                      album  \
# 0  7lmeHLHBe4nmXzuXc0HDjk                testify  The Battle Of Los Angeles
# 1  1wsRitfRRtWyEapl0q22o8        guerrilla radio  The Battle Of Los Angeles
# 2  1hR0fIFK2qRG3f3RF70pb7       calm like a bomb  The Battle Of Los Angeles
# 3  2lbASgTSoDO7MTuLAXlTW0              mic check  The Battle Of Los Angeles
# 4  1MQTmpYOZ6fcMQc56Hdo7T  sleep now in the fire  The Battle Of Los Angeles
#
#                  album_id                       artists  \
# 0  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 1  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 2  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 3  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 4  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
#
#                    artist_ids  track_number  disc_number  explicit  \
# 0  ['2d0hyoQ5ynDBnkvAbJKORj']             1            1     False
# ...

# %%
# change artist names to lower case
df['artists'] = df['artists'].str.lower()

# %%
df[df['artists'] == '[\'drake\']'].head()
# Out:
#                             id                 name  \
# 944942  5r7WvQtyPfy1xch5zMgGRp  behind barz - bonus
# 981250  4yVY7YxPeLE6uKG42w67fQ  behind barz - bonus
# 984446  4B7fTyj1FIPvP9tT5X3DnR  behind barz - bonus
#
#                                                     album  \
# 944942  Top Boy (A Selection of Music Inspired by the ...
# 981250  Top Boy (A Selection of Music Inspired by the ...
# 984446                                Behind Barz (Bonus)
#
#                       album_id    artists                  artist_ids  \
# 944942  334X6XoNKUzpAQbm5FPsMh  ['drake']  ['3TVXtAsR1Inumwj472S9r4']
# 981250  1UprOkquVDGsY9hzss6AKk  ['drake']  ['3TVXtAsR1Inumwj472S9r4']
# 984446  7dkkh6qYHqduXSWQFhmQ0i  ['drake']  ['3TVXtAsR1Inumwj472S9r4']
#
#         track_number  disc_number  explicit  danceability  ...  speechiness  \
# 944942            17            1      True         0.854  ...        0.172
# 981250            17            1     False         0.856  ...        0.173
# ...

# %%
# find most popular artists in dataset
df['artists'].value_counts().head(10)
# Out:
# artists
# ['various artists']                              1753
# ['vitamin string quartet']                       1577
# ['aretha franklin']                              1209
# ['the city of prague philharmonic orchestra']    1042
# ["dan gibson's solitudes"]                        997
# ['bob dylan']                                     913
# ['the fall']                                      812
# ["pickin' on series"]                             774
# ['dolly parton']                                  747
# ['guided by voices']                              739
# Name: count, dtype: int64

# %%
df.columns.values
# Out:
# array(['id', 'name', 'album', 'album_id', 'artists', 'artist_ids',
#        'track_number', 'disc_number', 'explicit', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms',
#        'time_signature', 'year', 'release_date'], dtype=object)

# %%
# make histogram showing song release years

df.loc[df['year'] == 2020, 'artists'].value_counts().head(20)
# Out:
# artists
# ['songs to your eyes']                               172
# ['tkkg']                                             169
# ['lil b']                                            163
# ['superchunk']                                       158
# ['strong bad']                                       148
# ['matt johnson']                                     136
# ['4 star view']                                      128
# ['martin george selwood']                            116
# ['ludwig van beethoven', 'giuseppe bruno']           100
# ['sirius beat']                                       89
# ['elvis presley']                                     88
# ['ludwig van beethoven', 'konstantin scherbakov']     86
# ['grant macdonald']                                   85
# ['jojo']                                              84
# ['dj iceman']                                         82
# ['franz schubert', 'llŷr williams']                   77
# ...

# %%
df[df['artists'].str.contains('kanye west', case=False, na=False)]

# %%
""" What's Up?

Sexy Bitch (feat. Akon)

Love T.K.O.

Moonlight"""

my_songs = ['what\'s up', 'sexy bitch (feat. akon)', 'love t.k.o.', 'moonlight']
# check if soongs are in dataset
songs = df['name'].values
songs_in_data = []
for song in my_songs:
    if song in songs:
        songs_in_data.append(song)
# Out:
#                              id       name  \
# 1106209  3DBJRu1pAQfzNtVLKoYo6d  moonlight
# 519404   1nC2tehhUX3kgRY5plfGjr  what's up
# 1120914  72tRR9KZORcwX3kv8FD8Hr  moonlight
# 728619   50Sy3vwKif0AxE69SQumEb  moonlight
# 728370   5oBDoKZVzvR7Hwn298wFWp  moonlight
# 494124   7Ed0gUU4Qwa8lOVs1QujcT  moonlight
# 1122813  5jXmJifvUfyE618x4S4kpc  moonlight
# 166436   5MUCP7i2GK2N4evzbfy5yK  moonlight
# 810707   1hH30Es9sn1k1am0ru9xaI  moonlight
# 661077   4VqBmtKxE0RzuMbiSyA48Z  what's up
# 316396   3CDxhj29VpDB3pYcy0Hi9g  moonlight
# 713423   2wRC9ds1uwh4FfkI5Jykgr  what's up
# 145769   0NIItc0WAo5bepy0PqnPOI  moonlight
# 147686   7hRUlcx5q4ioRFG5ja3PSk  what's up
# 907408   3mGAGg9IjkeCgeLYm61OZw  moonlight
# 1116034  34ASbtL7iCHtsbNkZAWs1n  moonlight
# 55370    7kFlRl80ewD69RzU9MiaZG  moonlight
# 561722   4AKF83bcvvx4SaqeAkoQy3  what's up
# 434350   1ZQHfBZ3xQwhK909Ku1KPF  moonlight
# 220490   3Rtc0EpLcQbFyuXpqU6vgE  moonlight
#
# ...
